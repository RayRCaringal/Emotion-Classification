# %%
from datasets import load_dataset, Image
import torch
from torchvision.transforms import Compose, ColorJitter, ToTensor
from torch.utils.data import DataLoader

train = load_dataset("AutumnQiu/fer2013", split="train")

# %%
import matplotlib.pyplot as plt


print(train)
example = train[2]
img = example["image"]
label = example["label"]


print("Example", example)
plt.imshow(img)
plt.title(f"Label: {label}")
plt.axis("off")
# Out:
# Dataset({
#     features: ['label', 'image'],
#     num_rows: 28709
# })
# Example {'label': 0, 'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=48x48 at 0x28A52739C10>}
# (np.float64(-0.5), np.float64(47.5), np.float64(47.5), np.float64(-0.5))
